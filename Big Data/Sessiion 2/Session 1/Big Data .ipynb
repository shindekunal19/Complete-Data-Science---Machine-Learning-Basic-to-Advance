# %%
pip install XlsxWriter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %%
rw = pd.read_csv(r"heart.csv")
rw.head(2)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# 1              Yes  Very good          7     No            No         No

# %%
rw = rw[240001:300000]

# %%
rw
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 240001           No  34.70      No              No     No               0
# 240002           No  21.83      No              No     No               0
# 240003           No  25.09      No              No     No               6
# 240004          Yes  21.95      No              No     No               0
# 240005          Yes  21.41     Yes              No     No               0
# ...             ...    ...     ...             ...    ...             ...
# 299995           No  23.06      No              No     No               5
# 299996           No  31.89     Yes              No     No               0
# 299997           No  27.26      No              No     No               0
# 299998           No  23.11      No              No     No               0
# 299999           No  24.02      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59999 entries, 240001 to 299999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      59999 non-null  object
#  1   BMI               59999 non-null  float64
#  2   Smoking           59999 non-null  object
#  3   AlcoholDrinking   59999 non-null  object
#  4   Stroke            59999 non-null  object
#  5   PhysicalHealth    59999 non-null  int64
#  6   MentalHealth      59999 non-null  int64
#  7   DiffWalking       59999 non-null  object
#  8   Sex               59999 non-null  object
#  9   AgeCategory       59999 non-null  object
#  10  Race              59999 non-null  object
#  11  Diabetic          59999 non-null  object
#  12  PhysicalActivity  59999 non-null  object
#  13  GenHealth         59999 non-null  object
#  14  SleepTime         59999 non-null  int64
#  15  Asthma            59999 non-null  object
# ...

# %%
rw.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
rw.drop('PhysicalHealth',axis=1,inplace=True)   # To Delete Perticular Columns
rw.drop('MentalHealth',axis=1,inplace=True)
rw.drop('Race',axis=1,inplace=True)
rw.drop('PhysicalActivity',axis=1,inplace=True)
rw.drop('GenHealth',axis=1,inplace=True)
#rw.drop('Asthma',axis=1,inplace=True)
#rw.drop('KidneyDisease',axis=1,inplace=True)
#rw.drop('SkinCancer',axis=1,inplace=True)
rw.drop('AgeCategory',axis=1,inplace=True)

# %%
rw
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking     Sex  \
# 240001           No  34.70      No              No     No          No  Female
# 240002           No  21.83      No              No     No          No    Male
# 240003           No  25.09      No              No     No          No    Male
# 240004          Yes  21.95      No              No     No         Yes  Female
# 240005          Yes  21.41     Yes              No     No          No  Female
# ...             ...    ...     ...             ...    ...         ...     ...
# 299995           No  23.06      No              No     No          No    Male
# 299996           No  31.89     Yes              No     No          No  Female
# 299997           No  27.26      No              No     No          No    Male
# 299998           No  23.11      No              No     No          No    Male
# 299999           No  24.02      No              No     No          No  Female
#
# ...

# %%
HeartDisease = pd.get_dummies(rw['HeartDisease'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,HeartDisease],axis=1)
rw.drop('HeartDisease',axis=1,inplace=True)
rw.rename(columns = {'Yes':'HeartDisease'}, inplace = True)

# %%
AlcoholDrinking = pd.get_dummies(rw['AlcoholDrinking'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,AlcoholDrinking],axis=1)
rw.drop('AlcoholDrinking',axis=1,inplace=True)
rw.rename(columns = {'Yes':'AlcoholDrinking'}, inplace = True)

# %%
Smoking = pd.get_dummies(rw['Smoking'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,Smoking],axis=1)
rw.drop('Smoking',axis=1,inplace=True)
rw.rename(columns = {'Yes':'Smoking'}, inplace = True)

# %%
Stroke = pd.get_dummies(rw['Stroke'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,Stroke],axis=1)
rw.drop('Stroke',axis=1,inplace=True)
rw.rename(columns = {'Yes':'Stroke'}, inplace = True)

# %%
Sex = pd.get_dummies(rw['Sex'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,Sex],axis=1)
rw.drop('Sex',axis=1,inplace=True)
rw.rename(columns = {'Male':'Sex'}, inplace = True)

# %%
DiffWalking = pd.get_dummies(rw['DiffWalking'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,DiffWalking],axis=1)
rw.drop('DiffWalking',axis=1,inplace=True)
rw.rename(columns = {'Yes':'DiffWalking'}, inplace = True)

# %%
Diabetic = pd.get_dummies(rw['Diabetic'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,Diabetic],axis=1)
rw.drop('Diabetic',axis=1,inplace=True)
rw.rename(columns = {'Yes':'Diabetic'}, inplace = True)

# %%
Asthma = pd.get_dummies(rw['Asthma'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,Asthma],axis=1)
rw.drop('Asthma',axis=1,inplace=True)
rw.rename(columns = {'Yes':'Asthma'}, inplace = True)

# %%
KidneyDisease = pd.get_dummies(rw['KidneyDisease'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,KidneyDisease],axis=1)
rw.drop('KidneyDisease',axis=1,inplace=True)
rw.rename(columns = {'Yes':'KidneyDisease'}, inplace = True)

# %%
SkinCancer = pd.get_dummies(rw['SkinCancer'],drop_first=True)   # To Create Dummies # Remove String from Columns and replce with Numbers
rw = pd.concat([rw,SkinCancer],axis=1)
rw.drop('SkinCancer',axis=1,inplace=True)
rw.rename(columns = {'Yes':'SkinCancer'}, inplace = True)

# %%
rw.drop('No, borderline diabetes',axis=1,inplace=True)
rw.drop('Yes (during pregnancy)',axis=1,inplace=True)

# %%
rw
# Out:
#           BMI  SleepTime  HeartDisease  AlcoholDrinking  Smoking  Stroke  Sex  \
# 240001  34.70          7             0                0        0       0    0
# 240002  21.83          6             0                0        0       0    1
# 240003  25.09          8             0                0        0       0    1
# 240004  21.95          5             1                0        0       0    0
# 240005  21.41          6             1                0        1       0    0
# ...       ...        ...           ...              ...      ...     ...  ...
# 299995  23.06          6             0                0        0       0    1
# 299996  31.89          5             0                0        1       0    0
# 299997  27.26          8             0                0        0       0    1
# 299998  23.11          7             0                0        0       0    1
# 299999  24.02          7             0                0        0       0    0
#
# ...

# %%
rw.describe()  # Data Stat
# Out:
#                 BMI     SleepTime  HeartDisease  AlcoholDrinking  \
# count  59999.000000  59999.000000  59999.000000     59999.000000
# mean      28.305202      7.098802      0.082985         0.066701
# std        6.377536      1.419286      0.275861         0.249506
# min       12.270000      1.000000      0.000000         0.000000
# 25%       24.020000      6.000000      0.000000         0.000000
# 50%       27.280000      7.000000      0.000000         0.000000
# 75%       31.320000      8.000000      0.000000         0.000000
# max       94.660000     24.000000      1.000000         1.000000
#
#             Smoking        Stroke           Sex   DiffWalking      Diabetic  \
# count  59999.000000  59999.000000  59999.000000  59999.000000  59999.000000
# mean       0.392707      0.036734      0.481758      0.130452      0.125069
# std        0.488357      0.188109      0.499671      0.336803      0.330800
# ...

# %%
rw.info()  # Missing Data Inform
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59999 entries, 240001 to 299999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BMI              59999 non-null  float64
#  1   SleepTime        59999 non-null  int64
#  2   HeartDisease     59999 non-null  uint8
#  3   AlcoholDrinking  59999 non-null  uint8
#  4   Smoking          59999 non-null  uint8
#  5   Stroke           59999 non-null  uint8
#  6   Sex              59999 non-null  uint8
#  7   DiffWalking      59999 non-null  uint8
#  8   Diabetic         59999 non-null  uint8
#  9   Asthma           59999 non-null  uint8
#  10  KidneyDisease    59999 non-null  uint8
#  11  SkinCancer       59999 non-null  uint8
# dtypes: float64(1), int64(1), uint8(10)
# memory usage: 1.5 MB

# %%
rw=rw.dropna() # Missing Row Delete

# %% [markdown]
# Decide Dependant and Independant Elements in Data Set

# %%
x=rw.drop('HeartDisease',axis=1)  # decide all Indepentant Data

# %%
x
# Out:
#           BMI  SleepTime  AlcoholDrinking  Smoking  Stroke  Sex  DiffWalking  \
# 240001  34.70          7                0        0       0    0            0
# 240002  21.83          6                0        0       0    1            0
# 240003  25.09          8                0        0       0    1            0
# 240004  21.95          5                0        0       0    0            1
# 240005  21.41          6                0        1       0    0            0
# ...       ...        ...              ...      ...     ...  ...          ...
# 299995  23.06          6                0        0       0    1            0
# 299996  31.89          5                0        1       0    0            0
# 299997  27.26          8                0        0       0    1            0
# 299998  23.11          7                0        0       0    1            0
# 299999  24.02          7                0        0       0    0            0
#
# ...

# %%
y=rw['HeartDisease']  # Decide Depenet data

# %%
y
# Out:
# 240001    0
# 240002    0
# 240003    0
# 240004    1
# 240005    1
#          ..
# 299995    0
# 299996    0
# 299997    0
# 299998    0
# 299999    0
# Name: HeartDisease, Length: 59999, dtype: uint8

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(x,y,test_size=0.3)  # Traning 70% and Testing 30%

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41999 entries, 243285 to 297037
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BMI              41999 non-null  float64
#  1   SleepTime        41999 non-null  int64
#  2   AlcoholDrinking  41999 non-null  uint8
#  3   Smoking          41999 non-null  uint8
#  4   Stroke           41999 non-null  uint8
#  5   Sex              41999 non-null  uint8
#  6   DiffWalking      41999 non-null  uint8
#  7   Diabetic         41999 non-null  uint8
#  8   Asthma           41999 non-null  uint8
#  9   KidneyDisease    41999 non-null  uint8
#  10  SkinCancer       41999 non-null  uint8
# dtypes: float64(1), int64(1), uint8(9)
# memory usage: 1.3 MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18000 entries, 274138 to 249012
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BMI              18000 non-null  float64
#  1   SleepTime        18000 non-null  int64
#  2   AlcoholDrinking  18000 non-null  uint8
#  3   Smoking          18000 non-null  uint8
#  4   Stroke           18000 non-null  uint8
#  5   Sex              18000 non-null  uint8
#  6   DiffWalking      18000 non-null  uint8
#  7   Diabetic         18000 non-null  uint8
#  8   Asthma           18000 non-null  uint8
#  9   KidneyDisease    18000 non-null  uint8
#  10  SkinCancer       18000 non-null  uint8
# dtypes: float64(1), int64(1), uint8(9)
# memory usage: 580.1 KB

# %% [markdown]
# # Machine Learning Models
#
# Linear
# Logistic
# SVC
# KNN
# K Mean
# Desicion Tree
# Random Forest
# Naive Bayes

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression  # Choose Mode

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)  # Training
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)  # Testing

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))   # Model Evaluation
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     16509
#            1       0.57      0.08      0.14      1491
#
#     accuracy                           0.92     18000
#    macro avg       0.74      0.54      0.55     18000
# weighted avg       0.89      0.92      0.89     18000

# %%
rw.columns
# Out:
# Index(['BMI', 'SleepTime', 'HeartDisease', 'AlcoholDrinking', 'Smoking',
#        'Stroke', 'Sex', 'DiffWalking', 'Diabetic', 'Asthma', 'KidneyDisease',
#        'SkinCancer'],
#       dtype='object')

# %%
import pandas as pd

# Load the original Excel file
original_file =   # Replace with the path to your Excel file
df = pd.read_csv(original_file)

# Define the columns to select
selected_columns = ['BMI', 'SleepTime', 'HeartDisease', 'AlcoholDrinking', 'Smoking',
       'Stroke', 'Sex', 'DiffWalking', 'Diabetic', 'Asthma', 'KidneyDisease',
       'SkinCancer']

# Define the number of rows in each part
rows_per_part = 60000

# Calculate the number of parts needed
num_parts = len(df) // rows_per_part

# Split the original DataFrame into multiple DataFrames
data_frames = [df[selected_columns][i * rows_per_part:(i + 1) * rows_per_part] for i in range(num_parts)]

# Save each part to separate Excel files
for i, part_df in enumerate(data_frames, 1):
    excel_file_name = f'part_{i}.xlsx'
    part_df.to_excel(excel_file_name, index=False, engine='openpyxl')

print("Data split and saved to Excel files.")

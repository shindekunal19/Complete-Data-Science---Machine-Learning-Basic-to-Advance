# %%
import pandas as pd

# %%
df = pd.read_excel("/content/advertising.xlsx")

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#             Timestamp  Clicked on Ad
# 0 2016-03-27 00:53:11              0
# ...

# %%
df.drop("Ad Topic Line", axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                City  Male                 Country           Timestamp  \
# ...

# %%
df.drop("City", axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line  Male                 Country  \
# ...

# %%
df = df.drop(["Ad Topic Line","City","Male","Country","Timestamp"], axis=1)

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage  Clicked on Ad
# count           1000.000000     1000.00000
# mean             180.000100        0.50000
# std               43.902339        0.50025
# min              104.780000        0.00000
# 25%              138.830000        0.00000
# 50%              183.130000        0.50000
# 75%              218.792500        1.00000
# max              269.960000        1.00000

# %% [markdown]
# SHEET 1

# %%
df1 = df[df['Clicked on Ad']==0]

# %%
df2 = df[df['Clicked on Ad']==1]

# %%
df1.describe()
# Out:
#        Daily Time Spent on Site         Age  Area Income  \
# count                500.000000  500.000000    500.00000
# mean                  76.854620   31.684000  61385.58642
# std                    7.560031    6.212998   8904.06018
# min                   48.220000   19.000000  33239.20000
# 25%                   72.077500   27.000000  55606.66250
# 50%                   77.650000   31.000000  62275.40500
# 75%                   82.070000   36.000000  67518.78250
# max                   91.430000   53.000000  79484.80000
#
#        Daily Internet Usage  Clicked on Ad
# count            500.000000          500.0
# mean             214.513740            0.0
# std               23.874382            0.0
# min              146.190000            0.0
# 25%              198.487500            0.0
# 50%              216.365000            0.0
# 75%              231.865000            0.0
# max              267.010000            0.0

# %%
df2.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                500.000000  500.000000    500.000000
# mean                  53.145780   40.334000  48614.413740
# std                   12.822091    8.856598  14116.242232
# min                   32.600000   19.000000  13996.500000
# 25%                   42.837500   34.000000  39106.620000
# 50%                   51.530000   40.000000  49417.255000
# 75%                   62.075000   47.000000  59241.045000
# max                   91.370000   61.000000  78520.990000
#
#        Daily Internet Usage  Clicked on Ad
# count            500.000000          500.0
# mean             145.486460            1.0
# std               30.025826            0.0
# min              104.780000            1.0
# 25%              123.592500            1.0
# 50%              138.790000            1.0
# 75%              161.160000            1.0
# max              269.960000            1.0

# %% [markdown]
# SHEET 2

# %%
df1_split1 = df1[1:101]
df1_split2 = df1[101:201]
df1_split3 = df1[201:301]
df1_split4 = df1[301:401]
df1_split5 = df1[401:501]

# %%
df1_split1.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  75.915500   30.870000  62816.097500
# std                    7.719211    6.032998   7779.320173
# min                   49.580000   20.000000  45593.930000
# 25%                   70.037500   27.000000  57631.967500
# 50%                   76.610000   31.000000  62621.235000
# 75%                   81.542500   34.250000  68181.600000
# max                   89.910000   47.000000  77567.850000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             212.173500            0.0
# std               22.918833            0.0
# min              146.190000            0.0
# 25%              198.545000            0.0
# 50%              211.760000            0.0
# 75%              226.945000            0.0
# max              267.010000            0.0

# %%
df1_split2.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  78.156800   32.380000  62160.699000
# std                    6.204983    6.119649   8302.192719
# min                   65.650000   21.000000  34309.240000
# 25%                   73.627500   28.000000  57199.017500
# 50%                   78.990000   32.000000  62797.735000
# 75%                   82.742500   36.250000  67554.317500
# max                   90.970000   53.000000  78119.500000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             214.230300            0.0
# std               23.172543            0.0
# min              156.480000            0.0
# 25%              200.057500            0.0
# 50%              217.735000            0.0
# 75%              231.435000            0.0
# max              261.020000            0.0

# %%
df1_split3.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  76.426700   32.470000  61670.353700
# std                    7.671876    6.532676   9562.926318
# min                   56.390000   20.000000  38609.200000
# 25%                   72.790000   27.000000  55101.990000
# 50%                   78.235000   32.000000  63446.015000
# 75%                   81.272500   37.000000  68105.887500
# max                   91.430000   51.000000  79484.800000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             216.474800            0.0
# std               23.708223            0.0
# min              158.420000            0.0
# 25%              203.890000            0.0
# 50%              218.645000            0.0
# 75%              234.127500            0.0
# max              256.400000            0.0

# %%
df1_split4.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  76.882900   31.240000  60410.855600
# std                    7.855731    6.229808   9799.240252
# min                   48.220000   19.000000  33239.200000
# 25%                   73.097500   27.000000  53089.650000
# 50%                   77.060000   30.000000  61634.220000
# 75%                   82.615000   35.250000  67397.582500
# max                   91.100000   51.000000  76984.210000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             213.665800            0.0
# std               23.562877            0.0
# min              149.250000            0.0
# 25%              196.315000            0.0
# 50%              216.950000            0.0
# 75%              230.400000            0.0
# max              259.760000            0.0

# %%
df1_split5.describe()
# Out:
#        Daily Time Spent on Site        Age   Area Income  \
# count                 99.000000  99.000000     99.000000
# mean                  76.971414  31.424242  59850.088182
# std                    8.164590   6.119709   8797.864293
# min                   51.650000  19.000000  35521.880000
# 25%                   70.940000  27.000000  54340.475000
# 50%                   78.670000  31.000000  59967.190000
# 75%                   82.550000  34.500000  66433.945000
# max                   91.150000  50.000000  77871.750000
#
#        Daily Internet Usage  Clicked on Ad
# count             99.000000           99.0
# mean             215.619596            0.0
# std               25.909557            0.0
# min              161.420000            0.0
# 25%              195.805000            0.0
# 50%              217.370000            0.0
# 75%              236.010000            0.0
# max              261.520000            0.0

# %%
df2_split1 = df2[1:101]
df2_split2 = df2[101:201]
df2_split3 = df2[201:301]
df2_split4 = df2[301:401]
df2_split5 = df2[401:501]

# %%
df2_split1.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  53.339700   41.840000  48205.096700
# std                   13.079054    8.680316  14557.658589
# min                   33.210000   23.000000  17709.980000
# 25%                   42.810000   36.000000  36774.845000
# 50%                   50.380000   41.500000  49632.805000
# 75%                   62.272500   48.250000  59718.417500
# max                   88.970000   60.000000  76368.310000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             143.858800            1.0
# std               27.234696            0.0
# min              104.780000            1.0
# 25%              124.262500            1.0
# 50%              138.860000            1.0
# 75%              158.220000            1.0
# max              235.780000            1.0

# %%
df2_split2.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  53.874600   39.700000  50336.580400
# std                   13.190278    9.387828  14633.371602
# min                   33.520000   19.000000  19991.720000
# 25%                   42.010000   32.000000  41063.170000
# 50%                   52.960000   40.000000  51647.790000
# 75%                   62.155000   47.000000  62124.677500
# max                   80.030000   59.000000  76893.840000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             149.614500            1.0
# std               31.136429            0.0
# min              105.000000            1.0
# 25%              127.187500            1.0
# 50%              143.230000            1.0
# 75%              165.530000            1.0
# max              269.960000            1.0

# %%
df2_split3.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  53.810000   39.190000  48304.998700
# std                   12.771791    8.048709  14010.380073
# min                   32.840000   23.000000  18819.340000
# 25%                   43.785000   33.750000  37312.140000
# 50%                   52.405000   39.000000  49106.570000
# 75%                   63.395000   44.250000  59168.880000
# max                   84.290000   58.000000  75180.200000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             139.781100            1.0
# std               26.802555            0.0
# min              105.940000            1.0
# 25%              120.217500            1.0
# 50%              132.670000            1.0
# 75%              154.357500            1.0
# max              255.070000            1.0

# %%
df2_split4.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  52.411500   40.460000  48029.691600
# std                   12.043094    9.868243  14225.719371
# min                   32.600000   23.000000  13996.500000
# 25%                   43.137500   32.000000  41276.172500
# 50%                   51.965000   40.500000  48711.060000
# 75%                   60.432500   49.000000  57720.280000
# max                   87.270000   61.000000  78520.990000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             149.041200            1.0
# std               31.503004            0.0
# min              105.710000            1.0
# 25%              124.362500            1.0
# 50%              142.635000            1.0
# 75%              167.105000            1.0
# max              250.360000            1.0

# %%
df2_split5.describe()
# Out:
#        Daily Time Spent on Site       Age   Area Income  Daily Internet Usage  \
# count                 99.000000  99.00000     99.000000             99.000000
# mean                  52.154646  40.40404  48434.109091            145.271818
# std                   13.153108   8.10885  13112.536620             32.641007
# min                   32.600000  20.00000  18368.570000            105.040000
# 25%                   41.695000  34.00000  39575.440000            120.825000
# 50%                   50.480000  42.00000  49206.400000            138.460000
# 75%                   61.800000  46.00000  56406.605000            162.445000
# max                   91.370000  57.00000  75265.960000            255.570000
#
#        Clicked on Ad
# count           99.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %% [markdown]
# SHEET 3

# %%
random_df1 = df1.sample(n=100)

# %%
random_df1.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  77.581100   32.200000  61183.320700
# std                    6.577844    5.759489   8910.328288
# min                   60.700000   22.000000  33239.200000
# 25%                   74.027500   27.750000  55325.405000
# 50%                   77.705000   31.500000  62085.505000
# 75%                   82.060000   36.000000  67189.722500
# max                   91.430000   46.000000  79332.330000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             218.870100            0.0
# std               22.789957            0.0
# min              164.250000            0.0
# 25%              204.425000            0.0
# 50%              222.875000            0.0
# 75%              234.660000            0.0
# max              261.020000            0.0

# %%
random_df2 = df2.sample(n=100)

# %%
random_df2.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count                100.000000  100.000000    100.000000
# mean                  53.121300   41.580000  46885.582600
# std                   13.504287    8.549535  13334.468769
# min                   32.600000   23.000000  13996.500000
# 25%                   41.855000   35.000000  38279.105000
# 50%                   51.905000   42.000000  46872.390000
# 75%                   61.307500   49.000000  54813.142500
# max                   91.370000   58.000000  78520.990000
#
#        Daily Internet Usage  Clicked on Ad
# count            100.000000          100.0
# mean             145.411100            1.0
# std               32.062217            0.0
# min              105.000000            1.0
# 25%              120.502500            1.0
# 50%              134.850000            1.0
# 75%              163.787500            1.0
# max              258.620000            1.0

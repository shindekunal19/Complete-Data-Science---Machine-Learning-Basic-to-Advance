# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn import svm
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
#loading data
data_df = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
data_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
#Evaluating the target and finding out the potential skewness in the data
cols= ["#CD5C5C","#FF0000"]
ax = sns.countplot(x= data_df["DEATH_EVENT"], palette= cols)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '203'), Text(0, 0, '96')]

# %%
# Doing Univariate Analysis for statistical description and understanding of dispersion of data
data_df.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %%
#Doing Bivariate Analysis by examaning a corelation matrix of all the features using heatmap
cmap = sns.diverging_palette(2, 165, s=80, l=55, n=9)
corrmat = data_df.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
# Out:
# <Axes: >

# %%
#Evauating age distribution as per the deaths happened
plt.figure(figsize=(15,10))
Days_of_week=sns.countplot(x=data_df['age'],data=data_df, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
# Checking for potential outliers using the "Boxen and Swarm plots" of non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(10,7))
    sns.swarmplot(x=data_df["DEATH_EVENT"], y=data_df[i], color="black", alpha=0.7)
    sns.boxenplot(x=data_df["DEATH_EVENT"], y=data_df[i], palette=cols)
    plt.show()

# %%
# Plotting "Kernel Density Estimation (kde plot)" of time and age features -  both of which are significant ones.
sns.kdeplot(x=data_df["time"], y=data_df["age"], hue =data_df["DEATH_EVENT"], palette=cols)
# Out:
# <Axes: xlabel='time', ylabel='age'>

# %%
# Defining independent and dependent attributes in training and test sets
X=data_df.drop(["DEATH_EVENT"],axis=1)
y=data_df["DEATH_EVENT"]

# %%
# Setting up a standard scaler for the features and analyzing it thereafter
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_scaled= s_scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=col_names)
X_scaled.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#Plotting the scaled features using boxen plots
colors =["#CD5C5C","#F08080","#FA8072","#E9967A","#FFA07A"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_scaled,palette = colors)
plt.xticks(rotation=60)
plt.show()

# %%
#spliting variables into training and test sets
X_train, X_test, y_train,y_test = train_test_split(X_scaled,y,test_size=0.30,random_state=25)

# %%
# Instantiating the SVM algorithm
model1=svm.SVC()

# Fitting the model
model1.fit (X_train, y_train)

# Predicting the test variables
y_pred = model1.predict(X_test)

# Getting the score
model1.score (X_test, y_test)
# Out:
# 0.7888888888888889

# %%
# Printing classification report (since there was biasness in target labels)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84        60
#            1       0.69      0.67      0.68        30
#
#     accuracy                           0.79        90
#    macro avg       0.76      0.76      0.76        90
# weighted avg       0.79      0.79      0.79        90

# %%
# Getting the confusion matrix
cmap1 = sns.diverging_palette(2, 165, s=80, l=55, n=9)
plt.subplots(figsize=(10,7))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':25})
# Out:
# <Axes: >

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 25, epochs = 80,callbacks=[early_stopping], validation_split=0.25)
# Out:
# Epoch 1/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.5391 - loss: 0.6930 - val_accuracy: 0.8302 - val_loss: 0.6906
# Epoch 2/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6508 - loss: 0.6921 - val_accuracy: 0.8302 - val_loss: 0.6886
# Epoch 3/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6792 - loss: 0.6908 - val_accuracy: 0.8302 - val_loss: 0.6865
# Epoch 4/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6397 - loss: 0.6906 - val_accuracy: 0.8302 - val_loss: 0.6842
# Epoch 5/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6084 - loss: 0.6906 - val_accuracy: 0.8302 - val_loss: 0.6820
# Epoch 6/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5988 - loss: 0.6898 - val_accuracy: 0.8302 - val_loss: 0.6796
# Epoch 7/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6632 - loss: 0.6869 - val_accuracy: 0.8302 - val_loss: 0.6766
# Epoch 8/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6415 - loss: 0.6865 - val_accuracy: 0.8302 - val_loss: 0.6736
# Epoch 9/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6299 - loss: 0.6860 - val_accuracy: 0.8302 - val_loss: 0.6703
# Epoch 10/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6624 - loss: 0.6835 - val_accuracy: 0.8302 - val_loss: 0.6667
# Epoch 11/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6397 - loss: 0.6821 - val_accuracy: 0.8302 - val_loss: 0.6627
# Epoch 12/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6369 - loss: 0.6809 - val_accuracy: 0.8302 - val_loss: 0.6576
# Epoch 13/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6413 - loss: 0.6786 - val_accuracy: 0.8302 - val_loss: 0.6528
# Epoch 14/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6142 - loss: 0.6754 - val_accuracy: 0.8302 - val_loss: 0.6463
# Epoch 15/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6538 - loss: 0.6670 - val_accuracy: 0.8302 - val_loss: 0.6366
# Epoch 16/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6217 - loss: 0.6644 - val_accuracy: 0.8302 - val_loss: 0.6255
# Epoch 17/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6532 - loss: 0.6560 - val_accuracy: 0.8302 - val_loss: 0.6114
# Epoch 18/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6475 - loss: 0.6378 - val_accuracy: 0.8302 - val_loss: 0.5937
# Epoch 19/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6772 - loss: 0.6254 - val_accuracy: 0.8302 - val_loss: 0.5719
# Epoch 20/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6931 - loss: 0.6132 - val_accuracy: 0.8491 - val_loss: 0.5501
# Epoch 21/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7302 - loss: 0.6153 - val_accuracy: 0.8491 - val_loss: 0.5261
# Epoch 22/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6869 - loss: 0.5962 - val_accuracy: 0.9057 - val_loss: 0.5055
# Epoch 23/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7817 - loss: 0.5776 - val_accuracy: 0.9245 - val_loss: 0.4820
# Epoch 24/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7989 - loss: 0.5448 - val_accuracy: 0.9057 - val_loss: 0.4574
# Epoch 25/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7803 - loss: 0.5569 - val_accuracy: 0.8868 - val_loss: 0.4385
# Epoch 26/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8189 - loss: 0.5454 - val_accuracy: 0.9057 - val_loss: 0.4155
# Epoch 27/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8230 - loss: 0.5423 - val_accuracy: 0.9057 - val_loss: 0.3967
# Epoch 28/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8348 - loss: 0.4878 - val_accuracy: 0.9057 - val_loss: 0.3762
# Epoch 29/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8196 - loss: 0.4817 - val_accuracy: 0.9057 - val_loss: 0.3520
# Epoch 30/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8374 - loss: 0.4829 - val_accuracy: 0.9057 - val_loss: 0.3313
# Epoch 31/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8417 - loss: 0.4972 - val_accuracy: 0.8868 - val_loss: 0.3175
# Epoch 32/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8589 - loss: 0.4688 - val_accuracy: 0.8868 - val_loss: 0.3053
# Epoch 33/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8218 - loss: 0.4470 - val_accuracy: 0.8868 - val_loss: 0.2965
# Epoch 34/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8317 - loss: 0.4603 - val_accuracy: 0.8679 - val_loss: 0.2940
# Epoch 35/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8086 - loss: 0.4486 - val_accuracy: 0.8679 - val_loss: 0.2957
# Epoch 36/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8675 - loss: 0.4347 - val_accuracy: 0.8491 - val_loss: 0.2968
# Epoch 37/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8440 - loss: 0.3781 - val_accuracy: 0.8302 - val_loss: 0.2936
# Epoch 38/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8539 - loss: 0.3778 - val_accuracy: 0.8491 - val_loss: 0.2887
# Epoch 39/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8351 - loss: 0.4115 - val_accuracy: 0.8491 - val_loss: 0.2804
# Epoch 40/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8240 - loss: 0.4727 - val_accuracy: 0.8491 - val_loss: 0.2768
# Epoch 41/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7953 - loss: 0.4220 - val_accuracy: 0.8491 - val_loss: 0.2739
# Epoch 42/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8618 - loss: 0.3723 - val_accuracy: 0.8491 - val_loss: 0.2697
# Epoch 43/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8307 - loss: 0.4380 - val_accuracy: 0.8491 - val_loss: 0.2647
# Epoch 44/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8683 - loss: 0.4133 - val_accuracy: 0.8491 - val_loss: 0.2626
# Epoch 45/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8354 - loss: 0.3928 - val_accuracy: 0.8491 - val_loss: 0.2594
# Epoch 46/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8206 - loss: 0.3901 - val_accuracy: 0.8679 - val_loss: 0.2554
# Epoch 47/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8712 - loss: 0.3730 - val_accuracy: 0.8491 - val_loss: 0.2505
# Epoch 48/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8833 - loss: 0.3555 - val_accuracy: 0.8491 - val_loss: 0.2483
# Epoch 49/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8413 - loss: 0.3981 - val_accuracy: 0.8491 - val_loss: 0.2517
# Epoch 50/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8599 - loss: 0.3645 - val_accuracy: 0.8491 - val_loss: 0.2533
# Epoch 51/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8433 - loss: 0.4219 - val_accuracy: 0.8491 - val_loss: 0.2549
# Epoch 52/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8161 - loss: 0.4322 - val_accuracy: 0.8491 - val_loss: 0.2540
# Epoch 53/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8405 - loss: 0.4071 - val_accuracy: 0.8491 - val_loss: 0.2546
# Epoch 54/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8714 - loss: 0.3584 - val_accuracy: 0.8491 - val_loss: 0.2555
# Epoch 55/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8231 - loss: 0.4682 - val_accuracy: 0.8491 - val_loss: 0.2529
# Epoch 56/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8532 - loss: 0.3906 - val_accuracy: 0.8491 - val_loss: 0.2500
# Epoch 57/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8073 - loss: 0.4153 - val_accuracy: 0.8491 - val_loss: 0.2503
# Epoch 58/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8719 - loss: 0.3454 - val_accuracy: 0.8491 - val_loss: 0.2540
# Epoch 59/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8557 - loss: 0.3699 - val_accuracy: 0.8491 - val_loss: 0.2566
# Epoch 60/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8468 - loss: 0.3753 - val_accuracy: 0.8491 - val_loss: 0.2575
# Epoch 61/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8436 - loss: 0.4120 - val_accuracy: 0.8302 - val_loss: 0.2597
# Epoch 62/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8454 - loss: 0.4048 - val_accuracy: 0.8302 - val_loss: 0.2580
# Epoch 63/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8551 - loss: 0.3844 - val_accuracy: 0.8302 - val_loss: 0.2584
# Epoch 64/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8909 - loss: 0.4115 - val_accuracy: 0.8491 - val_loss: 0.2552
# Epoch 65/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8456 - loss: 0.4146 - val_accuracy: 0.8491 - val_loss: 0.2552
# Epoch 66/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8681 - loss: 0.3774 - val_accuracy: 0.8302 - val_loss: 0.2578
# Epoch 67/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8461 - loss: 0.3765 - val_accuracy: 0.8302 - val_loss: 0.2587
# Epoch 68/80
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8405 - loss: 0.3925 - val_accuracy: 0.8302 - val_loss: 0.2664

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy is', val_accuracy*100))
# Out:
# val_accuracy is: 85.18%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.4)
np.set_printoptions()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
# Getting the confusion matrix
cmap1 = sns.diverging_palette(2, 165, s=80, l=55, n=9)
plt.subplots(figsize=(10,7))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':25})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        60
#            1       0.67      0.80      0.73        30
#
#     accuracy                           0.80        90
#    macro avg       0.78      0.80      0.78        90
# weighted avg       0.81      0.80      0.80        90
